# %%
from IPython.display import display, HTML
display(HTML('<style>.container { width:90% !important; }</style>'))
from elasticsearch import Elasticsearch 
from elasticsearch import helpers
from sklearn.cluster import KMeans
import requests
from urllib.parse import urljoin
from time import gmtime, strftime
from itertools import product
import warnings
from scipy import stats
import plotly.graph_objs as go
import plotly.offline as offline
import pandas as pd
import numpy as np
import datetime
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# es.indices.create('reports', body=elasticsearch_settings_reports)

# %%
es=Elasticsearch([{'host':'localhost','port':9200}], timeout=300, max_retries=10)

# %%
from customeranalytics.data_storage_configurations.reports import Reports
# Out:
# /Users/caglanakpinar/opt/anaconda3/lib/python3.8/site-packages/plotly/graph_objs/_deprecations.py:143: DeprecationWarning:
#
# plotly.graph_objs.Annotation is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Annotation
#   - plotly.graph_objs.layout.scene.Annotation
# [Errno 20] Not a directory: '/Users/caglanakpinar/Desktop/temp_customer_analytics_folder/build_in_reports/.DS_Store'

# %%
create_build_in_reports = Reports()

# %%
create_build_in_reports.create_build_in_reports()
# Out:
# folder already exists
# folder already exists
# folder already exists
# index : main || report :  weekly_funnel
# index : main || report :  daily_clv
# index : main || report :  daily_funnel
# index : main || report :  daily_funnel_downloads
# index : main || report :  weekly_average_payment_amount
# index : main || report :  product_usage_before_after_orders_reject
# index : main || report :  ride
# index : main || report :  recency_clusters
# index : main || report :  weekly_cohort_from_2_to_3
# index : main || report :  daily_dimension_values
# index : main || report :  daily_cohort_from_3_to_4
# index : main || report :  promotion_comparison
# index : main || report :  deliver_kpis
# index : main || report :  promotion_usage_before_after_orders_reject
# index : main || report :  most_ordered_products
# index : main || report :  daily_organic_orders
# index : main || report :  monetary_clusters
# index : main || report :  frequency_recency
# index : main || report :  segments_change_monthly_before_after_amount
# index : main || report :  daily_promotion_revenue
# index : main || report :  daily_cohort_from_2_to_3
# index : main || report :  weekly_cohort_from_3_to_4
# index : main || report :  product_usage_before_after_orders_accept
# index : main || report :  client_feature_predicted
# index : main || report :  frequency_clusters
# index : main || report :  monthly_orders
# index : main || report :  daily_products_of_sales
# index : main || report :  hourly_funnel
# index : main || report :  weekly_average_order_per_user
# index : main || report :  ride_weekday_hour
# index : main || report :  daily_inorganic_ratio
# index : main || report :  daily_cohort_downloads
# index : main || report :  hourly_inorganic_ratio
# index : main || report :  promotion_number_of_customer
# index : main || report :  inorganic_orders_per_promotion_per_day
# index : main || report :  promotion_usage_before_after_orders_accept
# index : main || report :  recency_monetary
# index : main || report :  segments_change_monthly_before_after_orders
# index : main || report :  customer_journey
# index : main || report :  purchase_amount_distribution
# index : main || report :  dfunnel_anomaly
# index : main || report :  dcohort_anomaly_2
# index : main || report :  dimension_kpis
# index : main || report :  segments_change_weekly_before_after_orders
# index : main || report :  user_counts_per_order_seq
# index : main || report :  daily_cohort_from_1_to_2
# index : main || report :  hourly_organic_orders
# index : main || report :  prepare
# index : main || report :  weekly_cohort_downloads
# index : main || report :  hourly_funnel_downloads
# index : main || report :  product_usage_before_after_amount_accept
# index : main || report :  client_kpis
# index : main || report :  dorders_anomaly
# index : main || report :  churn
# index : main || report :  monthly_funnel_downloads
# index : main || report :  most_combined_products
# index : main || report :  avg_order_count_per_promo_per_cust
# index : main || report :  dcohort_anomaly
# index : main || report :  weekly_cohort_from_1_to_2
# index : main || report :  segments_change_daily_before_after_orders
# index : main || report :  rfm
# index : main || report :  promotion_usage_before_after_amount_accept
# index : main || report :  monthly_funnel
# index : main || report :  kpis
# index : main || report :  churn_weekly
# index : main || report :  clvsegments_amount
# index : main || report :  order_and_payment_amount_differences
# index : main || report :  prepare_weekday_hour
# index : main || report :  hourly_orders
# index : main || report :  clvrfm_anomaly
# index : main || report :  weekly_funnel_downloads
# index : main || report :  product_usage_before_after_amount_reject
# index : main || report :  weekly_average_session_per_user
# index : main || report :  daily_promotion_discount
# index : main || report :  product_kpis
# index : main || report :  segments_change_weekly_before_after_amount
# index : main || report :  deliver_weekday_hour
# index : main || report :  daily_orders
# index : main || report :  deliver
# index : main || report :  weekly_orders
# index : main || report :  segmentation
# index : main || report :  segments_change_daily_before_after_amount
# index : main || report :  most_ordered_categories
# index : main || report :  promotion_usage_before_after_amount_reject
# index : main || report :  monetary_frequency
# index : main || report :  promotion_kpis
# folder already exists
# folder already exists
# index : location_1 || report :  weekly_funnel
# index : location_1 || report :  daily_clv
# index : location_1 || report :  daily_funnel
# index : location_1 || report :  daily_funnel_downloads
# index : location_1 || report :  weekly_average_payment_amount
# index : location_1 || report :  product_usage_before_after_orders_reject
# index : location_1 || report :  ride
# index : location_1 || report :  recency_clusters
# index : location_1 || report :  weekly_cohort_from_2_to_3
# index : location_1 || report :  daily_dimension_values
# index : location_1 || report :  daily_cohort_from_3_to_4
# index : location_1 || report :  promotion_comparison
# index : location_1 || report :  deliver_kpis
# index : location_1 || report :  promotion_usage_before_after_orders_reject
# index : location_1 || report :  most_ordered_products
# index : location_1 || report :  daily_organic_orders
# index : location_1 || report :  monetary_clusters
# index : location_1 || report :  frequency_recency
# index : location_1 || report :  segments_change_monthly_before_after_amount
# index : location_1 || report :  daily_promotion_revenue
# index : location_1 || report :  daily_cohort_from_2_to_3
# index : location_1 || report :  weekly_cohort_from_3_to_4
# index : location_1 || report :  product_usage_before_after_orders_accept
# index : location_1 || report :  client_feature_predicted
# index : location_1 || report :  frequency_clusters
# index : location_1 || report :  monthly_orders
# index : location_1 || report :  daily_products_of_sales
# index : location_1 || report :  hourly_funnel
# index : location_1 || report :  weekly_average_order_per_user
# index : location_1 || report :  ride_weekday_hour
# index : location_1 || report :  daily_inorganic_ratio
# index : location_1 || report :  daily_cohort_downloads
# index : location_1 || report :  hourly_inorganic_ratio
# index : location_1 || report :  promotion_number_of_customer
# index : location_1 || report :  inorganic_orders_per_promotion_per_day
# index : location_1 || report :  promotion_usage_before_after_orders_accept
# index : location_1 || report :  recency_monetary
# index : location_1 || report :  segments_change_monthly_before_after_orders
# index : location_1 || report :  customer_journey
# index : location_1 || report :  purchase_amount_distribution
# index : location_1 || report :  dfunnel_anomaly
# index : location_1 || report :  dcohort_anomaly_2
# index : location_1 || report :  dimension_kpis
# index : location_1 || report :  segments_change_weekly_before_after_orders
# index : location_1 || report :  user_counts_per_order_seq
# index : location_1 || report :  daily_cohort_from_1_to_2
# index : location_1 || report :  hourly_organic_orders
# index : location_1 || report :  prepare
# index : location_1 || report :  weekly_cohort_downloads
# index : location_1 || report :  hourly_funnel_downloads
# index : location_1 || report :  product_usage_before_after_amount_accept
# index : location_1 || report :  client_kpis
# index : location_1 || report :  dorders_anomaly
# index : location_1 || report :  churn
# index : location_1 || report :  monthly_funnel_downloads
# index : location_1 || report :  most_combined_products
# index : location_1 || report :  avg_order_count_per_promo_per_cust
# index : location_1 || report :  dcohort_anomaly
# index : location_1 || report :  weekly_cohort_from_1_to_2
# index : location_1 || report :  segments_change_daily_before_after_orders
# index : location_1 || report :  rfm
# index : location_1 || report :  promotion_usage_before_after_amount_accept
# index : location_1 || report :  monthly_funnel
# index : location_1 || report :  kpis
# index : location_1 || report :  churn_weekly
# index : location_1 || report :  clvsegments_amount
# index : location_1 || report :  order_and_payment_amount_differences
# index : location_1 || report :  prepare_weekday_hour
# index : location_1 || report :  hourly_orders
# index : location_1 || report :  clvrfm_anomaly
# index : location_1 || report :  weekly_funnel_downloads
# index : location_1 || report :  product_usage_before_after_amount_reject
# index : location_1 || report :  weekly_average_session_per_user
# index : location_1 || report :  daily_promotion_discount
# index : location_1 || report :  product_kpis
# index : location_1 || report :  segments_change_weekly_before_after_amount
# index : location_1 || report :  deliver_weekday_hour
# index : location_1 || report :  daily_orders
# index : location_1 || report :  deliver
# index : location_1 || report :  weekly_orders
# index : location_1 || report :  segmentation
# index : location_1 || report :  segments_change_daily_before_after_amount
# index : location_1 || report :  most_ordered_categories
# index : location_1 || report :  promotion_usage_before_after_amount_reject
# index : location_1 || report :  monetary_frequency
# index : location_1 || report :  promotion_kpis
# folder already exists
# folder already exists
# index : location_2 || report :  weekly_funnel
# index : location_2 || report :  daily_clv
# index : location_2 || report :  daily_funnel
# index : location_2 || report :  daily_funnel_downloads
# index : location_2 || report :  weekly_average_payment_amount
# index : location_2 || report :  product_usage_before_after_orders_reject
# index : location_2 || report :  ride
# index : location_2 || report :  recency_clusters
# index : location_2 || report :  weekly_cohort_from_2_to_3
# index : location_2 || report :  daily_dimension_values
# index : location_2 || report :  daily_cohort_from_3_to_4
# index : location_2 || report :  promotion_comparison
# index : location_2 || report :  deliver_kpis
# index : location_2 || report :  promotion_usage_before_after_orders_reject
# index : location_2 || report :  most_ordered_products
# index : location_2 || report :  daily_organic_orders
# index : location_2 || report :  monetary_clusters
# index : location_2 || report :  frequency_recency
# index : location_2 || report :  segments_change_monthly_before_after_amount
# index : location_2 || report :  daily_promotion_revenue
# index : location_2 || report :  daily_cohort_from_2_to_3
# index : location_2 || report :  weekly_cohort_from_3_to_4
# index : location_2 || report :  product_usage_before_after_orders_accept
# index : location_2 || report :  client_feature_predicted
# index : location_2 || report :  frequency_clusters
# index : location_2 || report :  monthly_orders
# index : location_2 || report :  daily_products_of_sales
# index : location_2 || report :  hourly_funnel
# index : location_2 || report :  weekly_average_order_per_user
# index : location_2 || report :  ride_weekday_hour
# index : location_2 || report :  daily_inorganic_ratio
# index : location_2 || report :  daily_cohort_downloads
# index : location_2 || report :  hourly_inorganic_ratio
# index : location_2 || report :  promotion_number_of_customer
# index : location_2 || report :  inorganic_orders_per_promotion_per_day
# index : location_2 || report :  promotion_usage_before_after_orders_accept
# index : location_2 || report :  recency_monetary
# index : location_2 || report :  segments_change_monthly_before_after_orders
# index : location_2 || report :  customer_journey
# index : location_2 || report :  purchase_amount_distribution
# index : location_2 || report :  dfunnel_anomaly
# index : location_2 || report :  dcohort_anomaly_2
# index : location_2 || report :  dimension_kpis
# index : location_2 || report :  segments_change_weekly_before_after_orders
# index : location_2 || report :  user_counts_per_order_seq
# index : location_2 || report :  daily_cohort_from_1_to_2
# index : location_2 || report :  hourly_organic_orders
# index : location_2 || report :  prepare
# index : location_2 || report :  weekly_cohort_downloads
# index : location_2 || report :  hourly_funnel_downloads
# index : location_2 || report :  product_usage_before_after_amount_accept
# index : location_2 || report :  client_kpis
# index : location_2 || report :  dorders_anomaly
# index : location_2 || report :  churn
# index : location_2 || report :  monthly_funnel_downloads
# index : location_2 || report :  most_combined_products
# index : location_2 || report :  avg_order_count_per_promo_per_cust
# index : location_2 || report :  dcohort_anomaly
# index : location_2 || report :  weekly_cohort_from_1_to_2
# index : location_2 || report :  segments_change_daily_before_after_orders
# index : location_2 || report :  rfm
# index : location_2 || report :  promotion_usage_before_after_amount_accept
# index : location_2 || report :  monthly_funnel
# index : location_2 || report :  kpis
# index : location_2 || report :  churn_weekly
# index : location_2 || report :  clvsegments_amount
# index : location_2 || report :  order_and_payment_amount_differences
# index : location_2 || report :  prepare_weekday_hour
# index : location_2 || report :  hourly_orders
# index : location_2 || report :  clvrfm_anomaly
# index : location_2 || report :  weekly_funnel_downloads
# index : location_2 || report :  product_usage_before_after_amount_reject
# index : location_2 || report :  weekly_average_session_per_user
# index : location_2 || report :  daily_promotion_discount
# index : location_2 || report :  product_kpis
# index : location_2 || report :  segments_change_weekly_before_after_amount
# index : location_2 || report :  deliver_weekday_hour
# index : location_2 || report :  daily_orders
# index : location_2 || report :  deliver
# index : location_2 || report :  weekly_orders
# index : location_2 || report :  segmentation
# index : location_2 || report :  segments_change_daily_before_after_amount
# index : location_2 || report :  most_ordered_categories
# index : location_2 || report :  promotion_usage_before_after_amount_reject
# index : location_2 || report :  monetary_frequency
# index : location_2 || report :  promotion_kpis
# folder already exists
# folder already exists
# index : location_3 || report :  weekly_funnel
# index : location_3 || report :  daily_clv
# index : location_3 || report :  daily_funnel
# index : location_3 || report :  daily_funnel_downloads
# index : location_3 || report :  weekly_average_payment_amount
# index : location_3 || report :  product_usage_before_after_orders_reject
# index : location_3 || report :  ride
# index : location_3 || report :  recency_clusters
# index : location_3 || report :  weekly_cohort_from_2_to_3
# index : location_3 || report :  daily_dimension_values
# index : location_3 || report :  daily_cohort_from_3_to_4
# index : location_3 || report :  promotion_comparison
# index : location_3 || report :  deliver_kpis
# index : location_3 || report :  promotion_usage_before_after_orders_reject
# index : location_3 || report :  most_ordered_products
# index : location_3 || report :  daily_organic_orders
# index : location_3 || report :  monetary_clusters
# index : location_3 || report :  frequency_recency
# index : location_3 || report :  segments_change_monthly_before_after_amount
# index : location_3 || report :  daily_promotion_revenue
# index : location_3 || report :  daily_cohort_from_2_to_3
# index : location_3 || report :  weekly_cohort_from_3_to_4
# index : location_3 || report :  product_usage_before_after_orders_accept
# index : location_3 || report :  client_feature_predicted
# index : location_3 || report :  frequency_clusters
# index : location_3 || report :  monthly_orders
# index : location_3 || report :  daily_products_of_sales
# index : location_3 || report :  hourly_funnel
# index : location_3 || report :  weekly_average_order_per_user
# index : location_3 || report :  ride_weekday_hour
# index : location_3 || report :  daily_inorganic_ratio
# index : location_3 || report :  daily_cohort_downloads
# index : location_3 || report :  hourly_inorganic_ratio
# index : location_3 || report :  promotion_number_of_customer
# index : location_3 || report :  inorganic_orders_per_promotion_per_day
# index : location_3 || report :  promotion_usage_before_after_orders_accept
# index : location_3 || report :  recency_monetary
# index : location_3 || report :  segments_change_monthly_before_after_orders
# index : location_3 || report :  customer_journey
# index : location_3 || report :  purchase_amount_distribution
# index : location_3 || report :  dfunnel_anomaly
# index : location_3 || report :  dcohort_anomaly_2
# index : location_3 || report :  dimension_kpis
# index : location_3 || report :  segments_change_weekly_before_after_orders
# index : location_3 || report :  user_counts_per_order_seq
# index : location_3 || report :  daily_cohort_from_1_to_2
# index : location_3 || report :  hourly_organic_orders
# index : location_3 || report :  prepare
# index : location_3 || report :  weekly_cohort_downloads
# index : location_3 || report :  hourly_funnel_downloads
# index : location_3 || report :  product_usage_before_after_amount_accept
# index : location_3 || report :  client_kpis
# index : location_3 || report :  dorders_anomaly
# index : location_3 || report :  churn
# index : location_3 || report :  monthly_funnel_downloads
# index : location_3 || report :  most_combined_products
# index : location_3 || report :  avg_order_count_per_promo_per_cust
# index : location_3 || report :  dcohort_anomaly
# index : location_3 || report :  weekly_cohort_from_1_to_2
# index : location_3 || report :  segments_change_daily_before_after_orders
# index : location_3 || report :  rfm
# index : location_3 || report :  promotion_usage_before_after_amount_accept
# index : location_3 || report :  monthly_funnel
# index : location_3 || report :  kpis
# index : location_3 || report :  churn_weekly
# index : location_3 || report :  clvsegments_amount
# index : location_3 || report :  order_and_payment_amount_differences
# index : location_3 || report :  prepare_weekday_hour
# index : location_3 || report :  hourly_orders
# index : location_3 || report :  clvrfm_anomaly
# index : location_3 || report :  weekly_funnel_downloads
# index : location_3 || report :  product_usage_before_after_amount_reject
# index : location_3 || report :  weekly_average_session_per_user
# index : location_3 || report :  daily_promotion_discount
# index : location_3 || report :  product_kpis
# index : location_3 || report :  segments_change_weekly_before_after_amount
# index : location_3 || report :  deliver_weekday_hour
# index : location_3 || report :  daily_orders
# index : location_3 || report :  deliver
# index : location_3 || report :  weekly_orders
# index : location_3 || report :  segmentation
# index : location_3 || report :  segments_change_daily_before_after_amount
# index : location_3 || report :  most_ordered_categories
# index : location_3 || report :  promotion_usage_before_after_amount_reject
# index : location_3 || report :  monetary_frequency
# index : location_3 || report :  promotion_kpis

# %%
res = []
for r in es.search(index='reports', body={"size": 100000, "from": 0})['hits']['hits']:
    try:
        res.append({'report_name': r['_source']['report_name'],
                    'report_date': r['_source']['report_date'],
                    'time_period': r['_source']['report_types'].get('time_period', None),
                    'type': r['_source']['report_types'].get('type', None),
                    'from': r['_source']['report_types'].get('from', None),
                    'to': r['_source']['report_types'].get('to', None),
                    'abtest_type': r['_source']['report_types'].get('abtest_type', None),
                    'report_types': r['_source']['report_types'],
                    'index': r['_source']['index'],
                    'data': r['_source']['data']})
    except Exception as e:
        print(e)

# %%
folder

# %%
folder = "/Users/mac/Documents/GitHub/customer_analytics/customeranalytics/exploratory_analysis/sample_data/"
pd.DataFrame(list(pd.DataFrame(res).query("report_name == 'clv_prediction'")['data'])[-1]).query("client != 'newcomers'").to_csv(
folder + "sample_data_client_feature_predicted.csv", index=False)

# %%
pd.DataFrame(list(pd.DataFrame(res).query(
            "report_name == 'rfm''").sort_values(
            'report_date', ascending=False)['data'])[0])[['frequency', 'recency', 'monetary', 'client']]

# %%
list(pd.DataFrame(res).query("index == 'location_1' and report_name == 'rfm'")['data'])[0]

# %%
data = query_mls(configs, {"start_date": "2021-02-06"}, "segmentation")
rfm = query_exploratory_analysis({"date": None,
           "funnel": {"actions": ["download", "signup"], 
                      "purchase_actions": ["has_basket", "order_screen"], 
                      "host": 'localhost', 
                      "port": '9200', 
                      'download_index': 'downloads', 
                      'order_index': 'orders'},
           "cohort": {"has_download": True, "host": 'localhost', "port": '9200'},
           "products": {"has_download": True, "host": 'localhost', "port": '9200'},
           "rfm": {"host": 'localhost', "port": '9200', 'download_index': 'downloads', 'order_index': 'orders'},
           "stats": {"host": 'localhost', "port": '9200', 'download_index': 'downloads', 'order_index': 'orders'}
          }, queries, "rfm")

# %%
pd.merge(data, rfm, on='client', how='inner').iloc[0:2000].to_csv("sample_data_rfm.csv")

# %%
pip install screeninfo

# %%
from screeninfo import get_monitors
for m in get_monitors():
    print(str(m))

# %%
monitor = get_monitors()[0]
monitor[]

# %%
monitor.width

# %%
def get_widths_heights():
    monitor = get_monitors()[0]
    if moni

# %%
{1: "a"}[1]
